# %% [markdown]
# # Photons produced by Scintillation

# %% [markdown]
# In this notebook, we will study the spectrum of the photons produced by scintillation after the passage of the muon through the scintillator.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data file

file = "../build/output/step_output_Scintillator1.txt"

photon_id, energy, wavelength, time = np.loadtxt(file, usecols=[0, 1, 2, 3], unpack=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       4 # Load the data file
#       6 file = "../build/output/step_output_Scintillator1.txt"
# ----> 8 photon_id, energy, wavelength, time = np.loadtxt(file, usecols=[0, 1, 2, 3], unpack=True)
#
# File /opt/homebrew/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# ...

# %%
plt.figure()
plt.hist(energy, 100)
plt.xlabel("Energy (eV)")
plt.ylabel("Number of photons")
plt.show()

# %%
plt.figure()
plt.scatter(time, wavelength)
