# %% [markdown]
# # Photons produced by Scintillation

# %% [markdown]
# In this notebook, we will study the spectrum of the photons produced by scintillation after the passage of the muon through the scintillator.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data file

file = "../build/output/step_output_Scintillator1.txt"

# photon_id, energy, wavelength, time = np.loadtxt(file, usecols=[0, 1, 2, 3], unpack=True)[1:, 1:, 1:, 1:]
photon_id, energy, wavelength, time = np.loadtxt(file, usecols=[0, 1, 2, 3], skiprows=1, unpack=True)

# %%
plt.figure()
plt.hist(energy, 10)
plt.xlabel("Energy (eV)")
plt.ylabel("Number of photons")
plt.show()
