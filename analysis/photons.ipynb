# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "../build/output/step_output_Scintillator1.txt"
photon_id, energy, wavelength, time = np.loadtxt(file, usecols=[0, 1, 2, 3], skiprows=1, unpack=True)

# %%
plt.figure()
plt.hist(energy)
plt.xlabel("Number of photons")
plt.ylabel("Energy (eV)")
plt.show()

# %%
plt.figure()
plt.hist(wavelength, 10)
plt.xlabel("Number of photons")
plt.ylabel("Wavelength (nm)")
plt.show()
